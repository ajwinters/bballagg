# %% [markdown]
# # NBA Master Tables Creation
#
# This notebook creates and maintains the master tables that serve as the foundation for all NBA data pulls:
#
# 1. **Master Games**: All NBA games across seasons/leagues
# 2. **Master Players**: All NBA players across seasons
# 3. **Master Teams**: All NBA teams and their details
# 4. **Master Seasons**: Available seasons and their metadata
#
# These master tables provide the IDs needed for endpoint parameters in the systematic data collection process.

# %%
import pandas as pd
import time
import numpy as np
import sys
import os

# NBA API imports
from nba_api.stats.endpoints import playercareerstats
import nba_api.stats.endpoints as nbaapi
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams, players

# Database imports
import psycopg2
import re

# Add src directory to path for importing allintwo
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))
import allintwo

# %%
print("\n=== CREATING MASTER GAMES ===")
# Optimized games collection with error handling
gamesl = []
failed_seasons_games = []

for i, season in enumerate(seasons):
    try:
        print(f"Fetching games for season {season} ({i+1}/{len(seasons)})")
        gamefinder = leaguegamefinder.LeagueGameFinder(
            league_id_nullable='00', 
            season_type_nullable="Regular Season",
            season_nullable=season
        ).get_data_frames()[0]
        
        if len(gamefinder) > 0:
            gamesl.append(gamefinder)
            print(f"  ✓ Retrieved {len(gamefinder)} games")
        else:
            print(f"  ⚠ No games found for {season}")
            
        time.sleep(0.6)  # Rate limiting
        
    except Exception as e:
        print(f"  ✗ Failed to fetch games for {season}: {str(e)}")
        failed_seasons_games.append(season)
        time.sleep(2)  # Longer wait after error

# Combine all games
if gamesl:
    gamehistory = pd.concat(gamesl, axis=0, ignore_index=True)
    gamehistory['GAME_DATE'] = pd.to_datetime(gamehistory['GAME_DATE'])
    print(f"Total games collected: {len(gamehistory)}")
else:
    print("No games data collected!")

print("\n=== CREATING MASTER PLAYERS ===")
# Optimized players collection with error handling  
playersl = []
failed_seasons_players = []

for i, season in enumerate(seasons):
    try:
        print(f"Fetching players for season {season} ({i+1}/{len(seasons)})")
        playerfinder = nbaapi.leaguedashplayerbiostats.LeagueDashPlayerBioStats(season=season).get_data_frames()[0]
        
        if len(playerfinder) > 0:
            playerfinder['season'] = season
            playersl.append(playerfinder)
            print(f"  ✓ Retrieved {len(playerfinder)} players")
        else:
            print(f"  ⚠ No players found for {season}")
            
        time.sleep(0.4)  # Slightly faster for players
        
    except Exception as e:
        print(f"  ✗ Failed to fetch players for {season}: {str(e)}")
        failed_seasons_players.append(season)
        time.sleep(2)  # Longer wait after error

# Combine all players
if playersl:
    allplayers = pd.concat(playersl, axis=0, ignore_index=True)
    print(f"Total player records collected: {len(allplayers)}")
else:
    print("No players data collected!")

# Report any failures
if failed_seasons_games:
    print(f"\nFailed to fetch games for seasons: {failed_seasons_games}")
if failed_seasons_players:
    print(f"Failed to fetch players for seasons: {failed_seasons_players}")

print("\n=== CREATING AND POPULATING DATABASE TABLES ===")

# Drop existing tables to recreate
cursor = conn.cursor()
tables_to_drop = ['mastergames', 'masterplayers', 'masterteams', 'masterseasons']
for table in tables_to_drop:
    cursor.execute(f"DROP TABLE IF EXISTS {table};")
    print(f"Dropped table: {table}")

conn.commit()

# Clean column names for all datasets
gamehistory = allintwo.clean_column_names(gamehistory)
allplayers = allintwo.clean_column_names(allplayers)
master_teams = allintwo.clean_column_names(master_teams)
master_seasons = allintwo.clean_column_names(master_seasons)

# Create tables
datasets = [
    ('mastergames', gamehistory),
    ('masterplayers', allplayers), 
    ('masterteams', master_teams),
    ('masterseasons', master_seasons)
]

for table_name, df in datasets:
    print(f"Creating table: {table_name} with {len(df)} records")
    allintwo.create_table(conn, table_name, df)
    allintwo.insert_dataframe_to_rds(conn, df, table_name)
    print(f"  ✓ {table_name} completed")

print("\n🎉 All master tables created successfully!")
print("Tables created:", [name for name, _ in datasets])
# Out:
# === CREATING MASTER GAMES ===
# Fetching games for season 2024-25 (1/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2023-24 (2/79)
# Fetching games for season 2023-24 (2/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2022-23 (3/79)
# Fetching games for season 2022-23 (3/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2021-22 (4/79)
# Fetching games for season 2021-22 (4/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2020-21 (5/79)
# Fetching games for season 2020-21 (5/79)
#   ✓ Retrieved 2160 games
#   ✓ Retrieved 2160 games
# Fetching games for season 2019-20 (6/79)
# Fetching games for season 2019-20 (6/79)
#   ✓ Retrieved 2118 games
#   ✓ Retrieved 2118 games
# Fetching games for season 2018-19 (7/79)
# Fetching games for season 2018-19 (7/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2017-18 (8/79)
# Fetching games for season 2017-18 (8/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2016-17 (9/79)
# Fetching games for season 2016-17 (9/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2015-16 (10/79)
# Fetching games for season 2015-16 (10/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2014-15 (11/79)
# Fetching games for season 2014-15 (11/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2013-14 (12/79)
# Fetching games for season 2013-14 (12/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2012-13 (13/79)
# Fetching games for season 2012-13 (13/79)
#   ✓ Retrieved 2458 games
#   ✓ Retrieved 2458 games
# Fetching games for season 2011-12 (14/79)
# Fetching games for season 2011-12 (14/79)
#   ✓ Retrieved 1980 games
#   ✓ Retrieved 1980 games
# Fetching games for season 2010-11 (15/79)
# Fetching games for season 2010-11 (15/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2009-10 (16/79)
# Fetching games for season 2009-10 (16/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2008-09 (17/79)
# Fetching games for season 2008-09 (17/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2007-08 (18/79)
# Fetching games for season 2007-08 (18/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2006-07 (19/79)
# Fetching games for season 2006-07 (19/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2005-06 (20/79)
# Fetching games for season 2005-06 (20/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2004-05 (21/79)
# Fetching games for season 2004-05 (21/79)
#   ✓ Retrieved 2460 games
#   ✓ Retrieved 2460 games
# Fetching games for season 2003-04 (22/79)
# Fetching games for season 2003-04 (22/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 2002-03 (23/79)
# Fetching games for season 2002-03 (23/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 2001-02 (24/79)
# Fetching games for season 2001-02 (24/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 2000-01 (25/79)
# Fetching games for season 2000-01 (25/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 1999-00 (26/79)
# Fetching games for season 1999-00 (26/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 1998-99 (27/79)
# Fetching games for season 1998-99 (27/79)
#   ✓ Retrieved 1450 games
#   ✓ Retrieved 1450 games
# Fetching games for season 1997-98 (28/79)
# Fetching games for season 1997-98 (28/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 1996-97 (29/79)
# Fetching games for season 1996-97 (29/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 1995-96 (30/79)
# Fetching games for season 1995-96 (30/79)
#   ✓ Retrieved 2378 games
#   ✓ Retrieved 2378 games
# Fetching games for season 1994-95 (31/79)
# Fetching games for season 1994-95 (31/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1993-94 (32/79)
# Fetching games for season 1993-94 (32/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1992-93 (33/79)
# Fetching games for season 1992-93 (33/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1991-92 (34/79)
# Fetching games for season 1991-92 (34/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1990-91 (35/79)
# Fetching games for season 1990-91 (35/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1989-90 (36/79)
# Fetching games for season 1989-90 (36/79)
#   ✓ Retrieved 2214 games
#   ✓ Retrieved 2214 games
# Fetching games for season 1988-89 (37/79)
# Fetching games for season 1988-89 (37/79)
#   ✓ Retrieved 2050 games
#   ✓ Retrieved 2050 games
# Fetching games for season 1987-88 (38/79)
# Fetching games for season 1987-88 (38/79)
#   ✓ Retrieved 1886 games
#   ✓ Retrieved 1886 games
# Fetching games for season 1986-87 (39/79)
# Fetching games for season 1986-87 (39/79)
#   ✓ Retrieved 1886 games
#   ✓ Retrieved 1886 games
# Fetching games for season 1985-86 (40/79)
# Fetching games for season 1985-86 (40/79)
#   ✓ Retrieved 1886 games
#   ✓ Retrieved 1886 games
# Fetching games for season 1984-85 (41/79)
# Fetching games for season 1984-85 (41/79)
#   ✓ Retrieved 1886 games
#   ✓ Retrieved 1886 games
# Fetching games for season 1983-84 (42/79)
# Fetching games for season 1983-84 (42/79)
#   ✓ Retrieved 1886 games
#   ✓ Retrieved 1886 games
# Fetching games for season 1982-83 (43/79)
# Fetching games for season 1982-83 (43/79)
#   ⚠ No games found for 1982-83
#   ⚠ No games found for 1982-83
# Fetching games for season 1981-82 (44/79)
# Fetching games for season 1981-82 (44/79)
#   ⚠ No games found for 1981-82
#   ⚠ No games found for 1981-82
# Fetching games for season 1980-81 (45/79)
# Fetching games for season 1980-81 (45/79)
#   ⚠ No games found for 1980-81
#   ⚠ No games found for 1980-81
# Fetching games for season 1979-80 (46/79)
# Fetching games for season 1979-80 (46/79)
#   ⚠ No games found for 1979-80
#   ⚠ No games found for 1979-80
# Fetching games for season 1978-79 (47/79)
# Fetching games for season 1978-79 (47/79)
#   ⚠ No games found for 1978-79
#   ⚠ No games found for 1978-79
# Fetching games for season 1977-78 (48/79)
# Fetching games for season 1977-78 (48/79)
#   ⚠ No games found for 1977-78
#   ⚠ No games found for 1977-78
# Fetching games for season 1976-77 (49/79)
# Fetching games for season 1976-77 (49/79)
#   ⚠ No games found for 1976-77
#   ⚠ No games found for 1976-77
# Fetching games for season 1975-76 (50/79)
# Fetching games for season 1975-76 (50/79)
#   ⚠ No games found for 1975-76
#   ⚠ No games found for 1975-76
# Fetching games for season 1974-75 (51/79)
# Fetching games for season 1974-75 (51/79)
#   ⚠ No games found for 1974-75
#   ⚠ No games found for 1974-75
# Fetching games for season 1973-74 (52/79)
# Fetching games for season 1973-74 (52/79)
#   ⚠ No games found for 1973-74
#   ⚠ No games found for 1973-74
# Fetching games for season 1972-73 (53/79)
# Fetching games for season 1972-73 (53/79)
#   ⚠ No games found for 1972-73
#   ⚠ No games found for 1972-73
# Fetching games for season 1971-72 (54/79)
# Fetching games for season 1971-72 (54/79)
#   ⚠ No games found for 1971-72
#   ⚠ No games found for 1971-72
# Fetching games for season 1970-71 (55/79)
# Fetching games for season 1970-71 (55/79)
#   ⚠ No games found for 1970-71
#   ⚠ No games found for 1970-71
# Fetching games for season 1969-70 (56/79)
# Fetching games for season 1969-70 (56/79)
#   ⚠ No games found for 1969-70
#   ⚠ No games found for 1969-70
# Fetching games for season 1968-69 (57/79)
# Fetching games for season 1968-69 (57/79)
#   ⚠ No games found for 1968-69
#   ⚠ No games found for 1968-69
# Fetching games for season 1967-68 (58/79)
# Fetching games for season 1967-68 (58/79)
#   ⚠ No games found for 1967-68
#   ⚠ No games found for 1967-68
# Fetching games for season 1966-67 (59/79)
# Fetching games for season 1966-67 (59/79)
#   ⚠ No games found for 1966-67
#   ⚠ No games found for 1966-67
# Fetching games for season 1965-66 (60/79)
# Fetching games for season 1965-66 (60/79)
#   ⚠ No games found for 1965-66
#   ⚠ No games found for 1965-66
# Fetching games for season 1964-65 (61/79)
# Fetching games for season 1964-65 (61/79)
#   ⚠ No games found for 1964-65
#   ⚠ No games found for 1964-65
# Fetching games for season 1963-64 (62/79)
# Fetching games for season 1963-64 (62/79)
#   ⚠ No games found for 1963-64
#   ⚠ No games found for 1963-64
# Fetching games for season 1962-63 (63/79)
# Fetching games for season 1962-63 (63/79)
#   ⚠ No games found for 1962-63
#   ⚠ No games found for 1962-63
# Fetching games for season 1961-62 (64/79)
# Fetching games for season 1961-62 (64/79)
#   ⚠ No games found for 1961-62
#   ⚠ No games found for 1961-62
# Fetching games for season 1960-61 (65/79)
# Fetching games for season 1960-61 (65/79)
#   ⚠ No games found for 1960-61
#   ⚠ No games found for 1960-61
# Fetching games for season 1959-60 (66/79)
# Fetching games for season 1959-60 (66/79)
#   ⚠ No games found for 1959-60
#   ⚠ No games found for 1959-60
# Fetching games for season 1958-59 (67/79)
# Fetching games for season 1958-59 (67/79)
#   ⚠ No games found for 1958-59
#   ⚠ No games found for 1958-59
# Fetching games for season 1957-58 (68/79)
# Fetching games for season 1957-58 (68/79)
#   ⚠ No games found for 1957-58
#   ⚠ No games found for 1957-58
# Fetching games for season 1956-57 (69/79)
# Fetching games for season 1956-57 (69/79)
#   ⚠ No games found for 1956-57
#   ⚠ No games found for 1956-57
# Fetching games for season 1955-56 (70/79)
# Fetching games for season 1955-56 (70/79)
#   ⚠ No games found for 1955-56
#   ⚠ No games found for 1955-56
# Fetching games for season 1954-55 (71/79)
# Fetching games for season 1954-55 (71/79)
#   ⚠ No games found for 1954-55
#   ⚠ No games found for 1954-55
# Fetching games for season 1953-54 (72/79)
# Fetching games for season 1953-54 (72/79)
#   ⚠ No games found for 1953-54
#   ⚠ No games found for 1953-54
# Fetching games for season 1952-53 (73/79)
# Fetching games for season 1952-53 (73/79)
#   ⚠ No games found for 1952-53
#   ⚠ No games found for 1952-53
# Fetching games for season 1951-52 (74/79)
# Fetching games for season 1951-52 (74/79)
#   ⚠ No games found for 1951-52
#   ⚠ No games found for 1951-52
# Fetching games for season 1950-51 (75/79)
# Fetching games for season 1950-51 (75/79)
#   ⚠ No games found for 1950-51
#   ⚠ No games found for 1950-51
# Fetching games for season 1949-50 (76/79)
# Fetching games for season 1949-50 (76/79)
#   ⚠ No games found for 1949-50
#   ⚠ No games found for 1949-50
# Fetching games for season 1948-49 (77/79)
# Fetching games for season 1948-49 (77/79)
#   ⚠ No games found for 1948-49
#   ⚠ No games found for 1948-49
# Fetching games for season 1947-48 (78/79)
# Fetching games for season 1947-48 (78/79)
#   ⚠ No games found for 1947-48
#   ⚠ No games found for 1947-48
# Fetching games for season 1946-47 (79/79)
# Fetching games for season 1946-47 (79/79)
#   ⚠ No games found for 1946-47
#   ⚠ No games found for 1946-47
# C:\Users\ajwin\AppData\Local\Temp\ipykernel_9204\3771580200.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gamehistory = pd.concat(gamesl, axis=0, ignore_index=True)
# Total games collected: 95774
#
# === CREATING MASTER PLAYERS ===
# Fetching players for season 2024-25 (1/79)
#   ✓ Retrieved 569 players
#   ✓ Retrieved 569 players
# Fetching players for season 2023-24 (2/79)
# Fetching players for season 2023-24 (2/79)
#   ✓ Retrieved 572 players
#   ✓ Retrieved 572 players
# Fetching players for season 2022-23 (3/79)
# Fetching players for season 2022-23 (3/79)
#   ✓ Retrieved 539 players
#   ✓ Retrieved 539 players
# Fetching players for season 2021-22 (4/79)
# Fetching players for season 2021-22 (4/79)
#   ✓ Retrieved 605 players
#   ✓ Retrieved 605 players
# Fetching players for season 2020-21 (5/79)
# Fetching players for season 2020-21 (5/79)
#   ✓ Retrieved 540 players
#   ✓ Retrieved 540 players
# Fetching players for season 2019-20 (6/79)
# Fetching players for season 2019-20 (6/79)
#   ✓ Retrieved 529 players
#   ✓ Retrieved 529 players
# Fetching players for season 2018-19 (7/79)
# Fetching players for season 2018-19 (7/79)
#   ✓ Retrieved 530 players
#   ✓ Retrieved 530 players
# Fetching players for season 2017-18 (8/79)
# Fetching players for season 2017-18 (8/79)
#   ✓ Retrieved 540 players
#   ✓ Retrieved 540 players
# Fetching players for season 2016-17 (9/79)
# Fetching players for season 2016-17 (9/79)
#   ✓ Retrieved 486 players
#   ✓ Retrieved 486 players
# Fetching players for season 2015-16 (10/79)
# Fetching players for season 2015-16 (10/79)
#   ✓ Retrieved 476 players
#   ✓ Retrieved 476 players
# Fetching players for season 2014-15 (11/79)
# Fetching players for season 2014-15 (11/79)
#   ✓ Retrieved 492 players
#   ✓ Retrieved 492 players
# Fetching players for season 2013-14 (12/79)
# Fetching players for season 2013-14 (12/79)
#   ✓ Retrieved 482 players
#   ✓ Retrieved 482 players
# Fetching players for season 2012-13 (13/79)
# Fetching players for season 2012-13 (13/79)
#   ✓ Retrieved 469 players
#   ✓ Retrieved 469 players
# Fetching players for season 2011-12 (14/79)
# Fetching players for season 2011-12 (14/79)
#   ✓ Retrieved 478 players
#   ✓ Retrieved 478 players
# Fetching players for season 2010-11 (15/79)
# Fetching players for season 2010-11 (15/79)
#   ✓ Retrieved 452 players
#   ✓ Retrieved 452 players
# Fetching players for season 2009-10 (16/79)
# Fetching players for season 2009-10 (16/79)
#   ✓ Retrieved 442 players
#   ✓ Retrieved 442 players
# Fetching players for season 2008-09 (17/79)
# Fetching players for season 2008-09 (17/79)
#   ✓ Retrieved 445 players
#   ✓ Retrieved 445 players
# Fetching players for season 2007-08 (18/79)
# Fetching players for season 2007-08 (18/79)
#   ✓ Retrieved 451 players
#   ✓ Retrieved 451 players
# Fetching players for season 2006-07 (19/79)
# Fetching players for season 2006-07 (19/79)
#   ✓ Retrieved 458 players
#   ✓ Retrieved 458 players
# Fetching players for season 2005-06 (20/79)
# Fetching players for season 2005-06 (20/79)
#   ✓ Retrieved 458 players
#   ✓ Retrieved 458 players
# Fetching players for season 2004-05 (21/79)
# Fetching players for season 2004-05 (21/79)
#   ✓ Retrieved 464 players
#   ✓ Retrieved 464 players
# Fetching players for season 2003-04 (22/79)
# Fetching players for season 2003-04 (22/79)
#   ✓ Retrieved 442 players
#   ✓ Retrieved 442 players
# Fetching players for season 2002-03 (23/79)
# Fetching players for season 2002-03 (23/79)
#   ✓ Retrieved 428 players
#   ✓ Retrieved 428 players
# Fetching players for season 2001-02 (24/79)
# Fetching players for season 2001-02 (24/79)
#   ✓ Retrieved 440 players
#   ✓ Retrieved 440 players
# Fetching players for season 2000-01 (25/79)
# Fetching players for season 2000-01 (25/79)
#   ✓ Retrieved 441 players
#   ✓ Retrieved 441 players
# Fetching players for season 1999-00 (26/79)
# Fetching players for season 1999-00 (26/79)
#   ✓ Retrieved 439 players
#   ✓ Retrieved 439 players
# Fetching players for season 1998-99 (27/79)
# Fetching players for season 1998-99 (27/79)
#   ✓ Retrieved 440 players
#   ✓ Retrieved 440 players
# Fetching players for season 1997-98 (28/79)
# Fetching players for season 1997-98 (28/79)
#   ✓ Retrieved 439 players
#   ✓ Retrieved 439 players
# Fetching players for season 1996-97 (29/79)
# Fetching players for season 1996-97 (29/79)
#   ✓ Retrieved 441 players
#   ✓ Retrieved 441 players
# Fetching players for season 1995-96 (30/79)
# Fetching players for season 1995-96 (30/79)
#   ⚠ No players found for 1995-96
#   ⚠ No players found for 1995-96
# Fetching players for season 1994-95 (31/79)
# Fetching players for season 1994-95 (31/79)
#   ⚠ No players found for 1994-95
#   ⚠ No players found for 1994-95
# Fetching players for season 1993-94 (32/79)
# Fetching players for season 1993-94 (32/79)
#   ⚠ No players found for 1993-94
#   ⚠ No players found for 1993-94
# Fetching players for season 1992-93 (33/79)
# Fetching players for season 1992-93 (33/79)
#   ⚠ No players found for 1992-93
#   ⚠ No players found for 1992-93
# Fetching players for season 1991-92 (34/79)
# Fetching players for season 1991-92 (34/79)
#   ⚠ No players found for 1991-92
#   ⚠ No players found for 1991-92
# Fetching players for season 1990-91 (35/79)
# Fetching players for season 1990-91 (35/79)
#   ⚠ No players found for 1990-91
#   ⚠ No players found for 1990-91
# Fetching players for season 1989-90 (36/79)
# Fetching players for season 1989-90 (36/79)
#   ⚠ No players found for 1989-90
#   ⚠ No players found for 1989-90
# Fetching players for season 1988-89 (37/79)
# Fetching players for season 1988-89 (37/79)
#   ⚠ No players found for 1988-89
#   ⚠ No players found for 1988-89
# Fetching players for season 1987-88 (38/79)
# Fetching players for season 1987-88 (38/79)
#   ⚠ No players found for 1987-88
#   ⚠ No players found for 1987-88
# Fetching players for season 1986-87 (39/79)
# Fetching players for season 1986-87 (39/79)
#   ⚠ No players found for 1986-87
#   ⚠ No players found for 1986-87
# Fetching players for season 1985-86 (40/79)
# Fetching players for season 1985-86 (40/79)
#   ⚠ No players found for 1985-86
#   ⚠ No players found for 1985-86
# Fetching players for season 1984-85 (41/79)
# Fetching players for season 1984-85 (41/79)
#   ⚠ No players found for 1984-85
#   ⚠ No players found for 1984-85
# Fetching players for season 1983-84 (42/79)
# Fetching players for season 1983-84 (42/79)
#   ⚠ No players found for 1983-84
#   ⚠ No players found for 1983-84
# Fetching players for season 1982-83 (43/79)
# Fetching players for season 1982-83 (43/79)
#   ⚠ No players found for 1982-83
#   ⚠ No players found for 1982-83
# Fetching players for season 1981-82 (44/79)
# Fetching players for season 1981-82 (44/79)
#   ⚠ No players found for 1981-82
#   ⚠ No players found for 1981-82
# Fetching players for season 1980-81 (45/79)
# Fetching players for season 1980-81 (45/79)
#   ⚠ No players found for 1980-81
#   ⚠ No players found for 1980-81
# Fetching players for season 1979-80 (46/79)
# Fetching players for season 1979-80 (46/79)
#   ⚠ No players found for 1979-80
#   ⚠ No players found for 1979-80
# Fetching players for season 1978-79 (47/79)
# Fetching players for season 1978-79 (47/79)
#   ⚠ No players found for 1978-79
#   ⚠ No players found for 1978-79
# Fetching players for season 1977-78 (48/79)
# Fetching players for season 1977-78 (48/79)
#   ⚠ No players found for 1977-78
#   ⚠ No players found for 1977-78
# Fetching players for season 1976-77 (49/79)
# Fetching players for season 1976-77 (49/79)
#   ⚠ No players found for 1976-77
#   ⚠ No players found for 1976-77
# Fetching players for season 1975-76 (50/79)
# Fetching players for season 1975-76 (50/79)
#   ⚠ No players found for 1975-76
#   ⚠ No players found for 1975-76
# Fetching players for season 1974-75 (51/79)
# Fetching players for season 1974-75 (51/79)
#   ⚠ No players found for 1974-75
#   ⚠ No players found for 1974-75
# Fetching players for season 1973-74 (52/79)
# Fetching players for season 1973-74 (52/79)
#   ⚠ No players found for 1973-74
#   ⚠ No players found for 1973-74
# Fetching players for season 1972-73 (53/79)
# Fetching players for season 1972-73 (53/79)
#   ⚠ No players found for 1972-73
#   ⚠ No players found for 1972-73
# Fetching players for season 1971-72 (54/79)
# Fetching players for season 1971-72 (54/79)
#   ⚠ No players found for 1971-72
#   ⚠ No players found for 1971-72
# Fetching players for season 1970-71 (55/79)
# Fetching players for season 1970-71 (55/79)
#   ⚠ No players found for 1970-71
#   ⚠ No players found for 1970-71
# Fetching players for season 1969-70 (56/79)
# Fetching players for season 1969-70 (56/79)
#   ⚠ No players found for 1969-70
#   ⚠ No players found for 1969-70
# Fetching players for season 1968-69 (57/79)
# Fetching players for season 1968-69 (57/79)
#   ⚠ No players found for 1968-69
#   ⚠ No players found for 1968-69
# Fetching players for season 1967-68 (58/79)
# Fetching players for season 1967-68 (58/79)
#   ⚠ No players found for 1967-68
#   ⚠ No players found for 1967-68
# Fetching players for season 1966-67 (59/79)
# Fetching players for season 1966-67 (59/79)
#   ⚠ No players found for 1966-67
#   ⚠ No players found for 1966-67
# Fetching players for season 1965-66 (60/79)
# Fetching players for season 1965-66 (60/79)
#   ⚠ No players found for 1965-66
#   ⚠ No players found for 1965-66
# Fetching players for season 1964-65 (61/79)
# Fetching players for season 1964-65 (61/79)
#   ⚠ No players found for 1964-65
#   ⚠ No players found for 1964-65
# Fetching players for season 1963-64 (62/79)
# Fetching players for season 1963-64 (62/79)
#   ⚠ No players found for 1963-64
#   ⚠ No players found for 1963-64
# Fetching players for season 1962-63 (63/79)
# Fetching players for season 1962-63 (63/79)
#   ⚠ No players found for 1962-63
#   ⚠ No players found for 1962-63
# Fetching players for season 1961-62 (64/79)
# Fetching players for season 1961-62 (64/79)
#   ⚠ No players found for 1961-62
#   ⚠ No players found for 1961-62
# Fetching players for season 1960-61 (65/79)
# Fetching players for season 1960-61 (65/79)
#   ⚠ No players found for 1960-61
#   ⚠ No players found for 1960-61
# Fetching players for season 1959-60 (66/79)
# Fetching players for season 1959-60 (66/79)
#   ⚠ No players found for 1959-60
#   ⚠ No players found for 1959-60
# Fetching players for season 1958-59 (67/79)
# Fetching players for season 1958-59 (67/79)
#   ⚠ No players found for 1958-59
#   ⚠ No players found for 1958-59
# Fetching players for season 1957-58 (68/79)
# Fetching players for season 1957-58 (68/79)
#   ⚠ No players found for 1957-58
#   ⚠ No players found for 1957-58
# Fetching players for season 1956-57 (69/79)
# Fetching players for season 1956-57 (69/79)
#   ⚠ No players found for 1956-57
#   ⚠ No players found for 1956-57
# Fetching players for season 1955-56 (70/79)
# Fetching players for season 1955-56 (70/79)
#   ⚠ No players found for 1955-56
#   ⚠ No players found for 1955-56
# Fetching players for season 1954-55 (71/79)
# Fetching players for season 1954-55 (71/79)
#   ⚠ No players found for 1954-55
#   ⚠ No players found for 1954-55
# Fetching players for season 1953-54 (72/79)
# Fetching players for season 1953-54 (72/79)
#   ⚠ No players found for 1953-54
#   ⚠ No players found for 1953-54
# Fetching players for season 1952-53 (73/79)
# Fetching players for season 1952-53 (73/79)
#   ⚠ No players found for 1952-53
#   ⚠ No players found for 1952-53
# Fetching players for season 1951-52 (74/79)
# Fetching players for season 1951-52 (74/79)
#   ⚠ No players found for 1951-52
#   ⚠ No players found for 1951-52
# Fetching players for season 1950-51 (75/79)
# Fetching players for season 1950-51 (75/79)
#   ⚠ No players found for 1950-51
#   ⚠ No players found for 1950-51
# Fetching players for season 1949-50 (76/79)
# Fetching players for season 1949-50 (76/79)
#   ⚠ No players found for 1949-50
#   ⚠ No players found for 1949-50
# Fetching players for season 1948-49 (77/79)
# Fetching players for season 1948-49 (77/79)
#   ⚠ No players found for 1948-49
#   ⚠ No players found for 1948-49
# Fetching players for season 1947-48 (78/79)
# Fetching players for season 1947-48 (78/79)
#   ⚠ No players found for 1947-48
#   ⚠ No players found for 1947-48
# Fetching players for season 1946-47 (79/79)
# Fetching players for season 1946-47 (79/79)
#   ⚠ No players found for 1946-47
#   ⚠ No players found for 1946-47
# Total player records collected: 13987
#
# === CREATING AND POPULATING DATABASE TABLES ===
# Total player records collected: 13987
#
# === CREATING AND POPULATING DATABASE TABLES ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 76
#      73 print("\n=== CREATING AND POPULATING DATABASE TABLES ===")
#      75 # Drop existing tables to recreate
# ---> 76 cursor = conn.cursor()
#      77 tables_to_drop = ['mastergames', 'masterplayers', 'masterteams', 'masterseasons']
#      78 for table in tables_to_drop:
#
# AttributeError: 'NoneType' object has no attribute 'cursor'

# %%
# Configuration and Setup
print("Starting Master Tables Creation Process...")

# Try database connection
try:
    conn = allintwo.connect_to_rds('thebigone', 'ajwin', 'CharlesBark!23', 'nba-rds-instance.c9wwc0ukkiu5.us-east-1.rds.amazonaws.com')
    db_connected = conn is not None
    print("✓ Database connected successfully")
except Exception as e:
    print(f"⚠ Database connection failed: {str(e)}")
    print("Continuing with data collection for local validation...")
    db_connected = False
    conn = None

# Generate comprehensive seasons list (1946-47 to current)
def generate_seasons(start_year=1946, end_year=2025):
    """Generate NBA seasons in proper format"""
    seasons = []
    for i in range(start_year, end_year):
        seasons.append(f"{i}-{str(i+1)[2:].zfill(2)}")
    return seasons[::-1]  # Reverse to get most recent first

seasons = generate_seasons()
print(f"Generated {len(seasons)} seasons: {seasons[:5]}...{seasons[-5:]}")

# Create Master Teams table
print("\n=== CREATING MASTER TEAMS ===")
teams_data = teams.get_teams()
master_teams = pd.DataFrame(teams_data)
master_teams_clean = allintwo.clean_column_names(master_teams.copy())
print(f"Retrieved {len(master_teams)} teams")
print(master_teams.head())

# Create Master Seasons table
print("\n=== CREATING MASTER SEASONS ===")
master_seasons = pd.DataFrame({
    'season': seasons,
    'start_year': [int(s.split('-')[0]) for s in seasons],
    'end_year': [int('20' + s.split('-')[1]) if len(s.split('-')[1]) == 2 else int('19' + s.split('-')[1]) for s in seasons],
    'created_date': pd.Timestamp.now()
})
master_seasons_clean = allintwo.clean_column_names(master_seasons.copy())
print(f"Created {len(master_seasons)} seasons")
print(master_seasons.head())

# Save locally for now
print("\n=== SAVING DATA LOCALLY ===")
master_teams.to_csv('../data/master_teams.csv', index=False)
master_seasons.to_csv('../data/master_seasons.csv', index=False)
print("✓ Master teams and seasons saved locally")
# Out:
# Starting Master Tables Creation Process...
# Error connecting to RDS: connection to server at "nba-rds-instance.c9wwc0ukkiu5.us-east-1.rds.amazonaws.com" (44.208.170.145), port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# ✓ Database connected successfully
# Generated 79 seasons: ['2024-25', '2023-24', '2022-23', '2021-22', '2020-21']...['1950-51', '1949-50', '1948-49', '1947-48', '1946-47']
#
# === CREATING MASTER TEAMS ===
# Retrieved 30 teams
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966
#
# === CREATING MASTER SEASONS ===
# Created 79 seasons
#     season  start_year  end_year               created_date
# 0  2024-25        2024      2025 2025-08-07 21:34:58.582994
# 1  2023-24        2023      2024 2025-08-07 21:34:58.582994
# 2  2022-23        2022      2023 2025-08-07 21:34:58.582994
# 3  2021-22        2021      2022 2025-08-07 21:34:58.582994
# 4  2020-21        2020      2021 2025-08-07 21:34:58.582994
#
# === SAVING DATA LOCALLY ===
# ✓ Master teams and seasons saved locally
# Error connecting to RDS: connection to server at "nba-rds-instance.c9wwc0ukkiu5.us-east-1.rds.amazonaws.com" (44.208.170.145), port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# ✓ Database connected successfully
# Generated 79 seasons: ['2024-25', '2023-24', '2022-23', '2021-22', '2020-21']...['1950-51', '1949-50', '1948-49', '1947-48', '1946-47']
#
# === CREATING MASTER TEAMS ===
# Retrieved 30 teams
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966
#
# === CREATING MASTER SEASONS ===
# Created 79 seasons
#     season  start_year  end_year               created_date
# 0  2024-25        2024      2025 2025-08-07 21:34:58.582994
# 1  2023-24        2023      2024 2025-08-07 21:34:58.582994
# 2  2022-23        2022      2023 2025-08-07 21:34:58.582994
# 3  2021-22        2021      2022 2025-08-07 21:34:58.582994
# 4  2020-21        2020      2021 2025-08-07 21:34:58.582994
#
# === SAVING DATA LOCALLY ===
# ✓ Master teams and seasons saved locally

# %%
print("=== MASTER TABLES VALIDATION ===")

# Test database connection
conn = allintwo.connect_to_rds('thebigone', 'ajwin', 'CharlesBark!23', 'nba-rds-instance.c9wwc0ukkiu5.us-east-1.rds.amazonaws.com')

# Validate all master tables
master_tables = ['mastergames', 'masterplayers', 'masterteams', 'masterseasons']

for table_name in master_tables:
    try:
        df = allintwo.fetch_table_to_dataframe(conn, table_name)
        print(f"\n📊 {table_name.upper()}:")
        print(f"  Records: {len(df):,}")
        print(f"  Columns: {len(df.columns)}")
        
        # Show sample data
        if len(df) > 0:
            print("  Sample data:")
            display(df.head(3))
            
            # Table-specific insights
            if table_name == 'mastergames':
                date_range = pd.to_datetime(df['gamedate'])
                print(f"  Date range: {date_range.min().strftime('%Y-%m-%d')} to {date_range.max().strftime('%Y-%m-%d')}")
                print(f"  Unique games: {df['gameid'].nunique():,}")
                
            elif table_name == 'masterplayers':
                print(f"  Unique players: {df['playerid'].nunique():,}")
                print(f"  Seasons covered: {df['season'].nunique()}")
                
            elif table_name == 'masterteams':
                print(f"  Total teams: {len(df)}")
                
            elif table_name == 'masterseasons':
                print(f"  Season range: {df['season'].min()} to {df['season'].max()}")
        else:
            print("  ⚠ No data found!")
            
    except Exception as e:
        print(f"❌ Failed to validate {table_name}: {str(e)}")

print(f"\n✅ Master tables validation complete!")
# Out:
# Connected to RDS PostgreSQL database
# Data fetched successfully from mastergames table.
