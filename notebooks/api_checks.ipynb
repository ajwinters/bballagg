# %%
import nba_api.stats.endpoints as nbaapi
import pandas as pd
#         ("PlayerDashboardByClutch", {"player_id": 2544, "last_n_games": 30}, True),
# test
df = nbaapi.playerdashboardbygamesplits.PlayerDashboardByGameSplits(player_id=2544,date_from_nullable='2024-11-25',date_to_nullable='2024-11-30').get_data_frames()[3]

# %%
df
# Out:
#          GROUP_SET          GROUP_VALUE  GP  W  L  W_PCT        MIN  FGM  FGA  \
# 0  By Score Margin                 Tied   3  1  2  0.333   4.641667    0    0
# 1  By Score Margin         1 - 5 Points   3  1  2  0.333  48.753333    8   21
# 2  By Score Margin        6 - 10 Points   3  1  2  0.333  17.928333    4   10
# 3  By Score Margin       11 - 15 Points   2  1  1  0.500  19.331667    6   11
# 4  By Score Margin       16 - 20 Points   2  1  1  0.500   3.333333    1    1
# 5  By Score Margin  more than 20 Points   1  0  1  0.000   7.350000    1    4
#
#    FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  \
# 0   0.000     0     0    0.000    0    0     0.0     0     1    1    2    0
# 1   0.381     1     7    0.143    2    2     1.0     1    12   13    9   10
# 2   0.400     0     1    0.000    0    0     0.0     2     2    4   10    0
# 3   0.545     0     2    0.000    0    0     0.0     1     3    4    4    5
# ...
