# %%
import pandas as pd
import time
import numpy as np
from nba_api.stats.endpoints import playercareerstats
import nba_api.stats.endpoints as nbaapi

pd.set_option('display.max_columns', 500)

### 
testplayer='203076'
testgame = '0022201200'
testteam = '1610612755'

### LOADING IN GAMES
#games = pd.read_csv('gamehistory.csv')
#games[games['GAME_ID']==22201200]
#gameids = games['GAME_ID'].drop_duplicates()

# bxv2 = nbaapi.boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=testgame).get_data_frames()
bxv3 = nbaapi.boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=testgame).get_data_frames()
# bsdv2 = nbaapi.boxscoredefensivev2.BoxScoreDefensiveV2(game_id=testgame).get_data_frames()
# bsffv2 = nbaapi.boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id=testgame).get_data_frames()
bsffv3 = nbaapi.boxscorefourfactorsv3.BoxScoreFourFactorsV3(game_id=testgame).get_data_frames()
bshv2 = nbaapi.boxscorehustlev2.BoxScoreHustleV2(game_id=testgame).get_data_frames()
# bsmuv2 = nbaapi.boxscorematchupsv3.BoxScoreMatchupsV3(game_id=testgame).get_data_frames() ### An Interesting One
# bsmcv2 = nbaapi.boxscoremiscv2.BoxScoreMiscV2(game_id=testgame).get_data_frames()
bsmcv3 = nbaapi.boxscoremiscv3.BoxScoreMiscV3(game_id=testgame).get_data_frames()
# bsptv2 = nbaapi.boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id=testgame).get_data_frames()
bsptv3 = nbaapi.boxscoreplayertrackv3.BoxScorePlayerTrackV3(game_id=testgame).get_data_frames()
# bsscv2 = nbaapi.boxscorescoringv2.BoxScoreScoringV2(game_id=testgame).get_data_frames()
bsscv3 = nbaapi.boxscorescoringv3.BoxScoreScoringV3(game_id=testgame).get_data_frames()
# bssv2 = nbaapi.boxscoresummaryv2.BoxScoreSummaryV2(game_id=testgame).get_data_frames() ## BETTER FOR JUST GAME INFO
# bstv2 = nbaapi.boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=testgame).get_data_frames()
bstv3 = nbaapi.boxscoretraditionalv3.BoxScoreTraditionalV3(game_id=testgame).get_data_frames()
# bsuv2 = nbaapi.boxscoreusagev2.BoxScoreUsageV2(game_id=testgame).get_data_frames()
# bsuv3 = nbaapi.boxscoreusagev3.BoxScoreUsageV3(game_id=testgame).get_data_frames() #Useless at a team level

# %%
udfl = []

for i in gameids:
    dfs = [nbaapi.boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscorefourfactorsv3.BoxScoreFourFactorsV3(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscorehustlev2.BoxScoreHustleV2(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscoremiscv3.BoxScoreMiscV3(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscoreplayertrackv3.BoxScorePlayerTrackV3(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscorescoringv3.BoxScoreScoringV3(game_id=testgame).get_data_frames()[1],
    nbaapi.boxscoretraditionalv3.BoxScoreTraditionalV3(game_id=testgame).get_data_frames()[2]]

    merged_df = dfs[0].drop(columns=['teamCity', 'teamName', 'teamTricode', 'teamSlug','minutes'])

# Merge the rest of the DataFrames one by one
    for df in dfs[1:]:
        merged_df = merged_df.merge(df.drop(columns=['teamCity', 'teamName', 'teamTricode', 'teamSlug','minutes']), on=['gameId','teamId'], how='inner')  # Change 'inner' to 'left', 'right', or 'outer' as needed
    udfl.append(merged_df)
    print(merged_df.shape)
    time.sleep(3)
# Out:
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# (2, 114)
# ...

# %%
dfs = [bxv3[1],
bsffv3[1],
bshv2[1],
bsmcv3[1],
bsptv3[1],
bsptv3[1],
bsscv3[1],
bstv3[2]] ### bench and starters
import pandas as pd

# Start with the first DataFrame
merged_df = dfs[0].drop(columns=['teamCity', 'teamName', 'teamTricode', 'teamSlug','minutes'])

# Merge the rest of the DataFrames one by one
for df in dfs[1:]:
    merged_df = merged_df.merge(df.drop(columns=['teamCity', 'teamName', 'teamTricode', 'teamSlug','minutes']), on=['gameId','teamId'], how='inner')  # Change 'inner' to 'left', 'right', or 'outer' as needed

merged_df.to_csv('combineddatatest.csv')

# %%
bxv3 = nbaapi.boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=testgame,end_period=1).get_data_frames()

bxv3[1]
# Out:
#        gameId      teamId       teamCity teamName teamTricode teamSlug  \
# 0  0022201200  1610612762           Utah     Jazz         UTA     jazz
# 1  0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
#
#   minutes  estimatedOffensiveRating  offensiveRating  \
# 0  240:00                      96.0             95.1
# 1  240:00                     109.2            109.6
#
#    estimatedDefensiveRating  defensiveRating  estimatedNetRating  netRating  \
# 0                     109.2            109.6               -13.1      -14.5
# 1                      96.0             95.1                13.1       14.5
#
#    assistPercentage  assistToTurnover  assistRatio  \
# 0             0.585              1.26         18.0
# 1             0.744              2.23         19.3
#
#    offensiveReboundPercentage  defensiveReboundPercentage  reboundPercentage  \
# 0                       0.159                       0.656              0.448
# ...

# %%
nbaapi.boxscoreadvancedv3.BoxScoreAdvancedV3(game_id=testgame).get_data_frames()[1],
nbaapi.boxscorefourfactorsv3.BoxScoreFourFactorsV3(game_id=testgame).get_data_frames()[1],
nbaapi.boxscorehustlev2.BoxScoreHustleV2(game_id=testgame).get_data_frames()[1],
nbaapi.boxscoremiscv3.BoxScoreMiscV3(game_id=testgame).get_data_frames()[1],
nbaapi.boxscoreplayertrackv3.BoxScorePlayerTrackV3(game_id=testgame).get_data_frames()[1],
nbaapi.boxscorescoringv3.BoxScoreScoringV3(game_id=testgame).get_data_frames()[1],
nbaapi.boxscoretraditionalv3.BoxScoreTraditionalV3(game_id=testgame).get_data_frames()[2]

# %%
nbaapi.boxscoremiscv3.BoxScoreMiscV3(game_id=testgame,end_period=3).get_data_frames()[0]
# Out:
#         gameId      teamId       teamCity teamName teamTricode teamSlug  \
# 0   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 1   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 2   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 3   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 4   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 5   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 6   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 7   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 8   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 9   0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 10  0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# 11  0022201200  1610612760  Oklahoma City  Thunder         OKC  thunder
# ...
